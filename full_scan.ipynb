# %%
"""
Full scan notebook:

"""
# Out:
# '\nFull scan notebook:\n\n'

# %%
# Must have imports
import helper
from analyzer import Analyzer
from crawler import Crawler
from plotter import Plotter
from model import TextBlob, TrainedSentimentModel, Vader
import tensorflow

# %%
# Extra imports
import datetime
import time
import numpy as np
import tweepy

# %%
# Sample Config
config = {
	"user_auth": False, # autheticate as user or application
    "search": {
        "location": "darmstadt", # based on helper.GEOCODES dictionary
        "radius": 100, # optional default to 100
        "query": ['corona'], # query for searching (str array), either query or location has to be not empty
        "max_searches": 5000, # Default: 1000 max amount of searches 
        "num_results": 5000, # number of results with defined filter options
        "rate_limit": True,  # Default True: to turn off rate limit prints
        "filter": { # Filter applies to search
            "not_reply": True, # Filters for not replies when true, does nothing when false
            "not_retweet": True, # Filters for not retweets when true, does nothing when false
            "until": datetime.datetime(2020, 3, 1), # None or datetime (e.g. datetime.datetime(2020, 5, 20))
        }
    },
	"get_user": { # Optional, only when querying for users
		"good_user": True, # mandatory
		"search_type": "recent_user", # 'recent_user', 'recent_retweeted_user'
		"num_users": 30, # mandatory
        "unique_ids": True, # If true will remember user ids in session
	},
	"plot": {
		"title": "Testing",
	},
    # Full search not tested and should only be used with caution!
    "full_search": {
        "query": "#Corona lang:de", # the query used for full search
        "env_name": "dev", # your premium environment name
        "fromDate": "2020" + "01" + "15" + "1200", # Format: YYYYMMDDHHmm
        "toDate": "2020" + "06" + "01" + "1200"
    },
    # A full scan over 3 areas each hour, should run continuous
    "full_scan": {
        "active": True,
        "path": "saved_data/full_scan/",
        "locations": ["scan_1", "scan_2", "scan_3"], # All locations used by the scan
    }
}

# %%
# Load configs and init models
config = helper.init_config(config)

modl = TextBlob()
modlUs = TrainedSentimentModel()
vader_model = Vader()

craw = Crawler(config)
anal = Analyzer(config, vader_model)
plot = Plotter(config)
sentiment_pos_limit = 0.7
sentiment_neg_limit = -0.7

# %%
now = datetime.datetime.now()
goal = datetime.datetime(2020, 6, 29, 10, 0)
print(goal)
dif = goal - now
print(f"Waiting {dif.seconds} seconds")
# time.sleep(dif.seconds)
# Out:
# 2020-06-29 10:00:00
# Waiting 85006 seconds

# %%
# Analyze user:

craw.full_scan()
# users3 = craw.get_users()
# print(len(users))
# user = craw.get_user_from_id("ZDFheute")
# user = craw.get_user_from_id("BarackObama")
# tweets = craw.get_tweets()
# tweets = craw.get_timeline(users[0])
# len(tweets)
# Out:
# Scanning for Users...
# remaining requests: 1286
# tweets remaining: ~ 19290
# reset at: 2020-06-29 10:38:14
# reset in: 14:11
# remaining requests: 1021
# tweets remaining: ~ 15315
# reset at: 2020-06-29 10:38:14
# reset in: 13:11
# remaining requests: 826
# tweets remaining: ~ 12390
# reset at: 2020-06-29 10:38:14
# reset in: 12:29
# (3, 30)
# Saving new User List
# Scanning and saving tweets: 0
# Search reached end point
# Checked Tweets: 2915
# remaining requests: 668
# tweets remaining: ~ 10020
# reset at: 2020-06-29 10:38:14
# reset in: 11:48
# Search reached end point
# Checked Tweets: 1001
# remaining requests: 617
# tweets remaining: ~ 9255
# reset at: 2020-06-29 10:38:14
# reset in: 11:37
# Search reached end point
# Checked Tweets: 357
# remaining requests: 599
# tweets remaining: ~ 8985
# reset at: 2020-06-29 10:38:14
# reset in: 11:33
# Search reached end point
# Checked Tweets: 1891
# remaining requests: 504
# tweets remaining: ~ 7560
# reset at: 2020-06-29 10:38:14
# reset in: 11:09
# Search reached end point
# Checked Tweets: 1068
# remaining requests: 450
# tweets remaining: ~ 6750
# reset at: 2020-06-29 10:38:14
# reset in: 10:56
# Checked Tweets: 3236
# remaining requests: 287
# tweets remaining: ~ 4305
# reset at: 2020-06-29 10:38:14
# reset in: 10:21
# Search reached end point
# Checked Tweets: 267
# remaining requests: 273
# tweets remaining: ~ 4095
# reset at: 2020-06-29 10:38:14
# reset in: 10:18
# Search reached end point
# Checked Tweets: 462
# remaining requests: 249
# tweets remaining: ~ 3735
# reset at: 2020-06-29 10:38:14
# reset in: 10:13
# Search reached end point
# Checked Tweets: 2431
# remaining requests: 126
# tweets remaining: ~ 1890
# reset at: 2020-06-29 10:38:14
# reset in: 09:45
# Search reached end point
# Checked Tweets: 336
# remaining requests: 109
# tweets remaining: ~ 1635
# reset at: 2020-06-29 10:38:14
# reset in: 09:41
# Search reached end point
# Checked Tweets: 316
# remaining requests: 93
# tweets remaining: ~ 1395
# reset at: 2020-06-29 10:38:14
# reset in: 09:38
# Search reached end point
# Checked Tweets: 863
# remaining requests: 49
# tweets remaining: ~ 735
# reset at: 2020-06-29 10:38:14
# reset in: 09:28
# Search reached end point
# Checked Tweets: 774
# remaining requests: 10
# tweets remaining: ~ 150
# reset at: 2020-06-29 10:38:14
# reset in: 09:19
# Rate limit reached. Sleeping for: 557
# Search reached end point
# Checked Tweets: 532
# remaining requests: 1483
# tweets remaining: ~ 22245
# reset at: 2020-06-29 10:53:19
# reset in: 14:55
# Search reached end point
# Checked Tweets: 2409
# remaining requests: 1362
# tweets remaining: ~ 20430
# reset at: 2020-06-29 10:53:19
# reset in: 14:26
# Search reached end point
# Checked Tweets: 1051
# remaining requests: 1309
# tweets remaining: ~ 19635
# reset at: 2020-06-29 10:53:19
# reset in: 14:13
# Search reached end point
# Checked Tweets: 828
# remaining requests: 1267
# tweets remaining: ~ 19005
# reset at: 2020-06-29 10:53:19
# reset in: 14:03
# Search reached end point
# Checked Tweets: 353
# remaining requests: 1249
# tweets remaining: ~ 18735
# reset at: 2020-06-29 10:53:19
# reset in: 14:00
# Search reached end point
# Checked Tweets: 552
# remaining requests: 1221
# tweets remaining: ~ 18315
# reset at: 2020-06-29 10:53:19
# reset in: 13:53
# Checked Tweets: 269
# remaining requests: 1206
# tweets remaining: ~ 18090
# reset at: 2020-06-29 10:53:19
# reset in: 13:49
# Search reached end point
# Checked Tweets: 58
# remaining requests: 1203
# tweets remaining: ~ 18045
# reset at: 2020-06-29 10:53:19
# reset in: 13:49
# Checked Tweets: 3216
# remaining requests: 1041
# tweets remaining: ~ 15615
# reset at: 2020-06-29 10:53:19
# reset in: 13:10
# Search reached end point
# Checked Tweets: 1123
# remaining requests: 984
# tweets remaining: ~ 14760
# reset at: 2020-06-29 10:53:19
# reset in: 12:58
# Search reached end point
# Checked Tweets: 1015
# remaining requests: 933
# tweets remaining: ~ 13995
# reset at: 2020-06-29 10:53:19
# reset in: 12:45
# Checked Tweets: 188
# remaining requests: 922
# tweets remaining: ~ 13830
# reset at: 2020-06-29 10:53:19
# reset in: 12:42
# Search reached end point
# Checked Tweets: 823
# remaining requests: 880
# tweets remaining: ~ 13200
# reset at: 2020-06-29 10:53:19
# reset in: 12:33
# Search reached end point
# Checked Tweets: 31
# remaining requests: 878
# tweets remaining: ~ 13170
# reset at: 2020-06-29 10:53:19
# reset in: 12:32
# Search reached end point
# Checked Tweets: 155
# remaining requests: 870
# tweets remaining: ~ 13050
# reset at: 2020-06-29 10:53:19
# reset in: 12:30
# Search reached end point
# Checked Tweets: 175
# remaining requests: 861
# tweets remaining: ~ 12915
# reset at: 2020-06-29 10:53:19
# reset in: 12:28
# Search reached end point
# Checked Tweets: 1424
# remaining requests: 788
# tweets remaining: ~ 11820
# reset at: 2020-06-29 10:53:19
# reset in: 12:12
# Scanning and saving tweets: 1
# Search reached end point
# Checked Tweets: 98
# remaining requests: 783
# tweets remaining: ~ 11745
# reset at: 2020-06-29 10:53:19
# reset in: 12:11
# Search reached end point
# Checked Tweets: 405
# remaining requests: 762
# tweets remaining: ~ 11430
# reset at: 2020-06-29 10:53:19
# reset in: 12:06
# Search reached end point
# Checked Tweets: 1547
# remaining requests: 684
# tweets remaining: ~ 10260
# reset at: 2020-06-29 10:53:19
# reset in: 11:46
# Search reached end point
# Checked Tweets: 1254
# remaining requests: 621
# tweets remaining: ~ 9315
# reset at: 2020-06-29 10:53:19
# reset in: 11:33
# Search reached end point
# Checked Tweets: 92
# remaining requests: 616
# tweets remaining: ~ 9240
# reset at: 2020-06-29 10:53:19
# reset in: 11:32
# Search reached end point
# Checked Tweets: 2781
# remaining requests: 474
# tweets remaining: ~ 7110
# reset at: 2020-06-29 10:53:19
# reset in: 10:58
# Search reached end point
# Checked Tweets: 627
# remaining requests: 442
# tweets remaining: ~ 6630
# reset at: 2020-06-29 10:53:19
# reset in: 10:51
# Search reached end point
# Checked Tweets: 649
# remaining requests: 409
# tweets remaining: ~ 6135
# reset at: 2020-06-29 10:53:19
# reset in: 10:43
# Search reached end point
# Checked Tweets: 2126
# remaining requests: 302
# tweets remaining: ~ 4530
# reset at: 2020-06-29 10:53:19
# reset in: 10:17
# Search reached end point
# Checked Tweets: 1891
# remaining requests: 207
# tweets remaining: ~ 3105
# reset at: 2020-06-29 10:53:19
# reset in: 09:55
# Checked Tweets: 3216
# remaining requests: 44
# tweets remaining: ~ 660
# reset at: 2020-06-29 10:53:19
# reset in: 09:16
# Rate limit reached. Sleeping for: 547
# Checked Tweets: 3167
# remaining requests: 1382
# tweets remaining: ~ 20730
# reset at: 2020-06-29 11:08:25
# reset in: 14:30
# Search reached end point
# Checked Tweets: 407
# remaining requests: 1361
# tweets remaining: ~ 20415
# reset at: 2020-06-29 11:08:25
# reset in: 14:25
# Search reached end point
# Checked Tweets: 477
# remaining requests: 1337
# tweets remaining: ~ 20055
# reset at: 2020-06-29 11:08:25
# reset in: 14:20
# Search reached end point
# Checked Tweets: 266
# remaining requests: 1323
# tweets remaining: ~ 19845
# reset at: 2020-06-29 11:08:25
# reset in: 14:17
# Checked Tweets: 3205
# remaining requests: 1161
# tweets remaining: ~ 17415
# reset at: 2020-06-29 11:08:25
# reset in: 13:40
# Search reached end point
# Checked Tweets: 2013
# remaining requests: 1058
# tweets remaining: ~ 15870
# reset at: 2020-06-29 11:08:25
# reset in: 13:15
# Checked Tweets: 3167
# remaining requests: 894
# tweets remaining: ~ 13410
# reset at: 2020-06-29 11:08:25
# reset in: 12:34
# Search reached end point
# Checked Tweets: 624
# remaining requests: 862
# tweets remaining: ~ 12930
# reset at: 2020-06-29 11:08:25
# reset in: 12:27
# Search reached end point
# Checked Tweets: 730
# remaining requests: 825
# tweets remaining: ~ 12375
# reset at: 2020-06-29 11:08:25
# reset in: 12:19
# Search reached end point
# Checked Tweets: 939
# remaining requests: 778
# tweets remaining: ~ 11670
# reset at: 2020-06-29 11:08:25
# reset in: 12:09
# Checked Tweets: 3039
# remaining requests: 616
# tweets remaining: ~ 9240
# reset at: 2020-06-29 11:08:25
# reset in: 11:28
# Search reached end point
# Checked Tweets: 92
# remaining requests: 611
# tweets remaining: ~ 9165
# reset at: 2020-06-29 11:08:25
# reset in: 11:27
# Search reached end point
# Checked Tweets: 403
# remaining requests: 590
# tweets remaining: ~ 8850
# reset at: 2020-06-29 11:08:25
# reset in: 11:22
# Search reached end point
# Checked Tweets: 289
# remaining requests: 575
# tweets remaining: ~ 8625
# reset at: 2020-06-29 11:08:25
# reset in: 11:18
# Search reached end point
# Checked Tweets: 152
# remaining requests: 567
# tweets remaining: ~ 8505
# reset at: 2020-06-29 11:08:25
# reset in: 11:17
# Checked Tweets: 339
# remaining requests: 548
# tweets remaining: ~ 8220
# reset at: 2020-06-29 11:08:25
# reset in: 11:13
# Checked Tweets: 1588
# remaining requests: 467
# tweets remaining: ~ 7005
# reset at: 2020-06-29 11:08:25
# reset in: 10:56
# Search reached end point
# Checked Tweets: 654
# remaining requests: 433
# tweets remaining: ~ 6495
# reset at: 2020-06-29 11:08:25
# reset in: 10:48
# Search reached end point
# Checked Tweets: 2212
# remaining requests: 322
# tweets remaining: ~ 4830
# reset at: 2020-06-29 11:08:25
# reset in: 10:21
# Scanning and saving tweets: 2
# Search reached end point
# Checked Tweets: 1108
# remaining requests: 266
# tweets remaining: ~ 3990
# reset at: 2020-06-29 11:08:25
# reset in: 10:10
# Search reached end point
# Checked Tweets: 124
# remaining requests: 259
# tweets remaining: ~ 3885
# reset at: 2020-06-29 11:08:25
# reset in: 10:08
# Search reached end point
# Checked Tweets: 202
# remaining requests: 248
# tweets remaining: ~ 3720
# reset at: 2020-06-29 11:08:25
# reset in: 10:05
# Search reached end point
# Checked Tweets: 1262
# remaining requests: 184
# tweets remaining: ~ 2760
# reset at: 2020-06-29 11:08:25
# reset in: 09:52
# Search reached end point
# Checked Tweets: 1278
# remaining requests: 119
# tweets remaining: ~ 1785
# reset at: 2020-06-29 11:08:25
# reset in: 09:35
# Search reached end point
# Checked Tweets: 2237
# remaining requests: 7
# tweets remaining: ~ 105
# reset at: 2020-06-29 11:08:25
# reset in: 09:12
# Rate limit reached. Sleeping for: 551
# Search reached end point
# Checked Tweets: 180
# remaining requests: 1498
# tweets remaining: ~ 22470
# reset at: 2020-06-29 11:23:31
# reset in: 14:59
# Search reached end point
# Checked Tweets: 351
# remaining requests: 1480
# tweets remaining: ~ 22200
# reset at: 2020-06-29 11:23:31
# reset in: 14:55
# Search reached end point
# Checked Tweets: 1938
# remaining requests: 1383
# tweets remaining: ~ 20745
# reset at: 2020-06-29 11:23:31
# reset in: 14:34
# Search reached end point
# Checked Tweets: 219
# remaining requests: 1371
# tweets remaining: ~ 20565
# reset at: 2020-06-29 11:23:31
# reset in: 14:31
# Search reached end point
# Checked Tweets: 161
# remaining requests: 1362
# tweets remaining: ~ 20430
# reset at: 2020-06-29 11:23:31
# reset in: 14:29
# Search reached end point
# Checked Tweets: 2761
# remaining requests: 1223
# tweets remaining: ~ 18345
# reset at: 2020-06-29 11:23:31
# reset in: 13:58
# Search reached end point
# Checked Tweets: 365
# remaining requests: 1204
# tweets remaining: ~ 18060
# reset at: 2020-06-29 11:23:31
# reset in: 13:53
# Search reached end point
# Checked Tweets: 334
# remaining requests: 1187
# tweets remaining: ~ 17805
# reset at: 2020-06-29 11:23:31
# reset in: 13:50
# Search reached end point
# Checked Tweets: 6
# remaining requests: 1186
# tweets remaining: ~ 17790
# reset at: 2020-06-29 11:23:31
# reset in: 13:49
# Search reached end point
# Checked Tweets: 679
# remaining requests: 1152
# tweets remaining: ~ 17280
# reset at: 2020-06-29 11:23:31
# reset in: 13:42
# Search reached end point
# Checked Tweets: 1289
# remaining requests: 1087
# tweets remaining: ~ 16305
# reset at: 2020-06-29 11:23:31
# reset in: 13:26
# Search reached end point
# Checked Tweets: 354
# remaining requests: 1069
# tweets remaining: ~ 16035
# reset at: 2020-06-29 11:23:31
# reset in: 13:22
# Search reached end point
# Checked Tweets: 26
# remaining requests: 1067
# tweets remaining: ~ 16005
# reset at: 2020-06-29 11:23:31
# reset in: 13:21
# Search reached end point
# Checked Tweets: 1088
# remaining requests: 1012
# tweets remaining: ~ 15180
# reset at: 2020-06-29 11:23:31
# reset in: 13:09
# Search reached end point
# Checked Tweets: 1604
# remaining requests: 931
# tweets remaining: ~ 13965
# reset at: 2020-06-29 11:23:31
# reset in: 12:51
# Search reached end point
# Checked Tweets: 747
# remaining requests: 893
# tweets remaining: ~ 13395
# reset at: 2020-06-29 11:23:31
# reset in: 12:42
# Search reached end point
# Checked Tweets: 1175
# remaining requests: 834
# tweets remaining: ~ 12510
# reset at: 2020-06-29 11:23:31
# reset in: 12:28
# Search reached end point
# Checked Tweets: 2863
# remaining requests: 690
# tweets remaining: ~ 10350
# reset at: 2020-06-29 11:23:31
# reset in: 11:56

# %%
assert False

# %%
print(len(users))
print(len(users2))
print(len(users3))

# %%
x = craw.load_user_list()
print(len(x[0]))

# %%
craw.save_user_list(x)

# %%
# tweets = craw.get_full_timeline_until(users[0])
all_tweets = []
number_of_fails = 0
for user in users:    
    full_timeline = craw.get_full_timeline_until(user)
    if full_timeline == []:
        number_of_fails += 1
    else:
        all_tweets.append(full_timeline)
print(number_of_fails)

# %%
a = datetime.datetime.now()
b = datetime.datetime(2020,6,22, 12, 00)
print((a-b).seconds/3600 + (a-b).days * 24)
helper.hours_until(b)

# %%
flattened = [tweet for tweets in all_tweets for tweet in tweets]
print(len(flattened))
# anal.analyze_and_plot_sentiment_per_week(flattened, 0.7, -0.7)

# %%
anal.analyze_and_plot_sentiment_per_week(flattened, 0.8, -0.8)

# %%
anal.analyze_and_plot_sentiment_per_week(all_data, 0.5, -0.5)

# %%
filename = "saved_data/recent_timeline_tweets_1000.json"
tweets = craw.load_tweet(filename)
# craw.save_tweets(tweets, filename)
print(tweets[0].text)
print(tweets[1].text)
print(tweets[2].text)
print(tweets[3].text)

# %%
filename = "saved_data/full_timeline/2_31k.json"
tweets = craw.save_tweets(flattened, filename)

# %%
res = anal.analyze_sentiment(tweets)
res2 = anal.analyze_timeline(tweets)
# plot.simple_hist(res["ages"])

# %%
len(res2["ages"]["tweets_age"])

# %%
dataBlob = []
fullSenti = []
for tweet in tweets:
    senti = modl.get_polarity_without_preprocessing(tweet.text)
    fullSenti.append(senti)
    # TODO kann man auch auslagern
    # Beste Text Blob sentis: -0.7, 0.7
    if senti > 0.7:
        dataBlob.append('pos')
    elif senti < -0.7:
        dataBlob.append('neg')
    else:
        dataBlob.append('neut')

# %%
dataUs = modlUs.get_sentiment_labels_batch([tweet.text for tweet in tweets])
dataUs2 = modlUs.get_sentiment_label_without_preprocessing([tweet.text for tweet in tweets])

# %%
plot.simple_hist(dataUs)

# %%
plot.simple_hist(dataUs2)
